# %%
import numpy as np
from pySimio import *

# %%
# number of people (per origin/destination type) to generate and arrival rate
num_people = 20
LAMBDA = 5

# %%
# assuming people are reasonable, only 6 possible origin/destination pairs exist
WegE_ComE = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
WegE_Ctown = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
ComE_Ctown = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
Ctown_ComW = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
Ctown_WegW = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
ComW_WegW = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))

# %%
# create a BusStop object for each of the 6 bus stops
TDOG = BusStop('TDOG Depot')
WegE = BusStop('Wegmans-Eastbound')
WegW = BusStop('Wegmans-Westbound')
ComE = BusStop('Commons-Eastbound')
ComW = BusStop('Commons-Westbound')
Ctown = BusStop('Collegetown')

# %%
WegE.add_data({ComE: WegE_ComE, Ctown: WegE_Ctown})
ComE.add_data({Ctown: ComE_Ctown})
ComW.add_data({WegW: ComW_WegW})
Ctown.add_data({ComW: Ctown_ComW, WegW: Ctown_WegW})

# %%
# create a Route object for each of the 3 routes
Route1 = Route([TDOG, WegE, ComE, Ctown, ComW, WegE, TDOG], [0.5, 2, 2, 2, 2, 0.5], 1)
Route2 = Route([ComE, Ctown, ComW, ComE], [2, 2, 0.3], 2)
Route3 = Route([TDOG, WegE, ComE, ComW, WegW, TDOG], [0.5, 2, 2, 2, 0.5], 3)

# %%
Bus1 = Bus('Bus 1', Route1)
Bus2 = Bus('The Kenta Bus', Route3)

# %%
Ithaca = Map([Route1, Route2, Route2], [Bus1, Bus2], 
             {'TDOG Depot': TDOG, 'Wegmans-Eastbound': WegE, 'Wegmans-Westbound': WegW,
             'Commons-Eastbound': ComE, 'Commons-Westbound': ComW, 'Collegetown':Ctown})

# %%
Ithaca.simulate(18*60)
# Out:
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 1.5
# After arrival, occupancy = 0
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 1.5
# After arrival, occupancy = 0
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 6.958942386270245
# After arrival, occupancy = 0
# Bus Bus 1 arrived at Commons-Eastbound at t = 8.005710088000558
# After arrival, occupancy = 0
# Bus Bus 1 arrived at Collegetown at t = 13.102478215469146
# After arrival, occupancy = 1
# Bus The Kenta Bus arrived at Commons-Westbound at t = 13.896228826889349
# After arrival, occupancy = 0
# Bus Bus 1 arrived at Commons-Westbound at t = 19.130850020048925
# After arrival, occupancy = 2
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 19.80691060862555
# After arrival, occupancy = 0
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 21.30691060862555
# After arrival, occupancy = 0
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 24.887225816339985
# After arrival, occupancy = 2
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 26.393184308332984
# After arrival, occupancy = 0
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 26.80806505373973
# After arrival, occupancy = 14
# Bus Bus 1 arrived at Commons-Eastbound at t = 31.92927378804227
# After arrival, occupancy = 10
# Bus The Kenta Bus arrived at Commons-Westbound at t = 33.115181150355745
# After arrival, occupancy = 0
# Bus Bus 1 arrived at Collegetown at t = 37.77994593605898
# After arrival, occupancy = 8
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 39.29805807821991
# After arrival, occupancy = 3
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 40.79805807821991
# After arrival, occupancy = 3
# Bus Bus 1 arrived at Commons-Westbound at t = 44.45534534773577
# After arrival, occupancy = 9
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 45.803672028619545
# After arrival, occupancy = 3
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 50.14641883210162
# After arrival, occupancy = 9
# Bus The Kenta Bus arrived at Commons-Westbound at t = 51.70404676848754
# After arrival, occupancy = 3
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 52.24556773629247
# After arrival, occupancy = 29
# Bus Bus 1 arrived at Commons-Eastbound at t = 57.60297848885054
# After arrival, occupancy = 20
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 58.35233764270258
# After arrival, occupancy = 6
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 59.85233764270258
# After arrival, occupancy = 6
# Bus Bus 1 arrived at Collegetown at t = 62.92426096769903
# After arrival, occupancy = 17
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 65.80209152344663
# After arrival, occupancy = 6
# Bus Bus 1 arrived at Commons-Westbound at t = 69.92369844206235
# After arrival, occupancy = 19
# Bus The Kenta Bus arrived at Commons-Westbound at t = 71.00389088371067
# After arrival, occupancy = 6
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 75.685456832609
# After arrival, occupancy = 19
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 76.69357180430565
# After arrival, occupancy = 7
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 77.75278274959288
# After arrival, occupancy = 35
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 78.19357180430565
# After arrival, occupancy = 7
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 83.45290570728528
# After arrival, occupancy = 7
# Bus Bus 1 arrived at Commons-Eastbound at t = 84.52980847347825
# After arrival, occupancy = 27
# Bus The Kenta Bus arrived at Commons-Westbound at t = 89.83562210751965
# After arrival, occupancy = 7
# Bus Bus 1 arrived at Collegetown at t = 91.22052354167502
# After arrival, occupancy = 20
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 95.71365130022521
# After arrival, occupancy = 7
# Bus Bus 1 arrived at Commons-Westbound at t = 96.72809265153556
# After arrival, occupancy = 21
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 97.21365130022521
# After arrival, occupancy = 7
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 103.35050742123063
# After arrival, occupancy = 21
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 103.37810012684686
# After arrival, occupancy = 7
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 105.39347263173498
# After arrival, occupancy = 35
# Bus The Kenta Bus arrived at Commons-Westbound at t = 108.70685125906209
# After arrival, occupancy = 7
# Bus Bus 1 arrived at Commons-Eastbound at t = 112.19375465338823
# After arrival, occupancy = 28
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 114.56810683623581
# After arrival, occupancy = 5
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 116.06810683623581
# After arrival, occupancy = 5
# Bus Bus 1 arrived at Collegetown at t = 117.56264733384837
# After arrival, occupancy = 19
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 122.4659906419693
# After arrival, occupancy = 5
# Bus Bus 1 arrived at Commons-Westbound at t = 123.96903592820814
# After arrival, occupancy = 20
# Bus The Kenta Bus arrived at Commons-Westbound at t = 129.159539125992
# After arrival, occupancy = 5
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 130.3025408529669
# After arrival, occupancy = 20
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 131.995252718469
# After arrival, occupancy = 28
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 135.83191401632368
# After arrival, occupancy = 3
# Bus Bus 1 arrived at Commons-Eastbound at t = 137.09974510594415
# After arrival, occupancy = 24
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 137.33191401632368
# After arrival, occupancy = 3
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 143.6954260379173
# After arrival, occupancy = 3
# Bus Bus 1 arrived at Collegetown at t = 143.76677680275515
# After arrival, occupancy = 17
# Bus The Kenta Bus arrived at Commons-Westbound at t = 148.81624265216288
# After arrival, occupancy = 3
# Bus Bus 1 arrived at Commons-Westbound at t = 149.22436097607454
# After arrival, occupancy = 17
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 155.6327280393936
# After arrival, occupancy = 2
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 156.09171688216045
# After arrival, occupancy = 17
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 157.1327280393936
# After arrival, occupancy = 2
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 157.78596581329725
# After arrival, occupancy = 21
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 162.8433028983927
# After arrival, occupancy = 2
# Bus Bus 1 arrived at Commons-Eastbound at t = 163.81312836576106
# After arrival, occupancy = 18
# Bus The Kenta Bus arrived at Commons-Westbound at t = 169.57867530336165
# After arrival, occupancy = 2
# Bus Bus 1 arrived at Collegetown at t = 169.93754244812803
# After arrival, occupancy = 12
# Bus Bus 1 arrived at Commons-Westbound at t = 175.55429033185885
# After arrival, occupancy = 9
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 175.84586312686073
# After arrival, occupancy = 1
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 177.34586312686073
# After arrival, occupancy = 1
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 181.07321739228405
# After arrival, occupancy = 9
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 182.63397131010743
# After arrival, occupancy = 11
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 182.80677555064204
# After arrival, occupancy = 1
# Bus Bus 1 arrived at Commons-Eastbound at t = 187.68220316483388
# After arrival, occupancy = 10
# Bus The Kenta Bus arrived at Commons-Westbound at t = 188.1447014159478
# After arrival, occupancy = 1
# Bus Bus 1 arrived at Collegetown at t = 193.42432725823403
# After arrival, occupancy = 6
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 193.48271869272975
# After arrival, occupancy = 0
# Bus The Kenta Bus arrived at Wegmans-Eastbound at t = 194.98271869272975
# After arrival, occupancy = 0
# Bus Bus 1 arrived at Commons-Westbound at t = 198.91348149340647
# After arrival, occupancy = 4
# Bus The Kenta Bus arrived at Commons-Eastbound at t = 200.2932940584095
# After arrival, occupancy = 0
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 205.05909584805755
# After arrival, occupancy = 4
# Bus The Kenta Bus arrived at Commons-Westbound at t = 206.39530401448562
# After arrival, occupancy = 0
# Bus Bus 1 arrived at Wegmans-Eastbound at t = 206.57574710700362
# After arrival, occupancy = 5
# Bus The Kenta Bus arrived at Wegmans-Westbound at t = 212.47118417644484
# After arrival, occupancy = 0
# Bus Bus 1 arrived at Commons-