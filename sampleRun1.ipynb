# %%
import numpy as np
from pySimio import *

# %%
# number of people (per origin/destination type) to generate and arrival rate
num_people = 20
LAMBDA = 5

# %%
# assuming people are reasonable, only 6 possible origin/destination pairs exist
WegE_ComE = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
WegE_Ctown = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
ComE_Ctown = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
Ctown_ComW = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
Ctown_WegW = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
ComW_WegW = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))

# %%
# create a BusStop object for each of the 6 bus stops
TDOG = BusStop('TDOG Depot')
WegE = BusStop('Wegmans-Eastbound')
WegW = BusStop('Wegmans-Westbound')
ComE = BusStop('Commons-Eastbound')
ComW = BusStop('Commons-Westbound')
Ctown = BusStop('Collegetown')

# %%
WegE.add_data({ComE: WegE_ComE, Ctown: WegE_Ctown})
ComE.add_data({Ctown: ComE_Ctown})
ComW.add_data({WegW: ComW_WegW})
Ctown.add_data({ComW: Ctown_ComW, WegW: Ctown_WegW})

# %%
# create a Route object for each of the 3 routes
Route1 = Route([TDOG, WegE, ComE, Ctown, ComW, WegE, TDOG], [0.5, 2, 2, 2, 2, 0.5], 1)
Route2 = Route([ComE, Ctown, ComW, ComE], [2, 2, 0.3], 2)
Route3 = Route([TDOG, WegE, ComE, ComW, WegW, TDOG], [0.5, 2, 2, 2, 0.5], 3)

# %%
# Bus1 = Bus('Bus 1', Route1)
Bus2 = Bus('The Kenta Bus', Route2)

# %%
Ithaca = Map([Route1, Route2, Route2], [Bus2], 
             {'TDOG Depot': TDOG, 'Wegmans-Eastbound': WegE, 'Wegmans-Westbound': WegW,
             'Commons-Eastbound': ComE, 'Commons-Westbound': ComW, 'Collegetown':Ctown})

# %%
Ithaca.simulate(18*60)
# Out:
# 1
# The Kenta Bus : departure event at TDOG Depot at t = 0
#
# The Kenta Bus : arrival event at Collegetown at t = 1.5
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 1.5
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 8.029421766623887
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 8.029421766623887
#
# The Kenta Bus : arrival event at Collegetown at t = 14.781371718839827
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 14.781371718839827
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 20.751533780686827
# After arrival, occupancy = 1
#
# The Kenta Bus : departure event at Commons-Westbound at t = 20.751533780686827
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 21.651533780686826
# After arrival, occupancy = 1
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 21.651533780686826
#
# The Kenta Bus : arrival event at Collegetown at t = 26.939800679692258
# After arrival, occupancy = 3
#
# The Kenta Bus : departure event at Collegetown at t = 26.939800679692258
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 33.12540428867912
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Commons-Westbound at t = 33.12540428867912
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 34.02540428867912
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 34.02540428867912
#
# The Kenta Bus : arrival event at Collegetown at t = 40.56699133766589
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Collegetown at t = 40.56699133766589
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 47.54474409363822
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Commons-Westbound at t = 47.54474409363822
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 48.44474409363822
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 48.44474409363822
#
# The Kenta Bus : arrival event at Collegetown at t = 55.13991078805927
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Collegetown at t = 55.13991078805927
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 60.273420196740936
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Commons-Westbound at t = 60.273420196740936
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 61.173420196740935
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 61.173420196740935
#
# The Kenta Bus : arrival event at Collegetown at t = 67.97588700870965
# After arrival, occupancy = 6
#
# The Kenta Bus : departure event at Collegetown at t = 67.97588700870965
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 73.23974123857575
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Westbound at t = 73.23974123857575
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 74.13974123857575
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 74.13974123857575
#
# The Kenta Bus : arrival event at Collegetown at t = 80.79229568985653
# After arrival, occupancy = 8
#
# The Kenta Bus : departure event at Collegetown at t = 80.79229568985653
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 86.61530535295861
# After arrival, occupancy = 8
#
# The Kenta Bus : departure event at Commons-Westbound at t = 86.61530535295861
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 87.51530535295862
# After arrival, occupancy = 8
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 87.51530535295862
#
# The Kenta Bus : arrival event at Collegetown at t = 93.80384364704405
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Collegetown at t = 93.80384364704405
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 100.42731081754928
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Westbound at t = 100.42731081754928
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 101.32731081754929
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 101.32731081754929
#
# The Kenta Bus : arrival event at Collegetown at t = 108.17058838462931
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Collegetown at t = 108.17058838462931
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 114.67224191526428
# After arrival, occupancy = 6
#
# The Kenta Bus : departure event at Commons-Westbound at t = 114.67224191526428
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 115.57224191526429
# After arrival, occupancy = 6
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 115.57224191526429
#
# The Kenta Bus : arrival event at Collegetown at t = 122.00847688723844
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Collegetown at t = 122.00847688723844
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 127.90806410373574
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Commons-Westbound at t = 127.90806410373574
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 128.80806410373575
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 128.80806410373575
#
# The Kenta Bus : arrival event at Collegetown at t = 135.48262268834654
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Collegetown at t = 135.48262268834654
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 141.6619949615192
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Commons-Westbound at t = 141.6619949615192
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 142.56199496151922
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 142.56199496151922
#
# The Kenta Bus : arrival event at Collegetown at t = 148.98825926263564
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Collegetown at t = 148.98825926263564
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 155.11608087387413
# After arrival, occupancy = 2
#
# The Kenta Bus : departure event at Commons-Westbound at t = 155.11608087387413
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 156.01608087387413
# After arrival, occupancy = 2
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 156.01608087387413
#
# The Kenta Bus : arrival event at Collegetown at t = 162.77713937042617
# After arrival, occupancy = 2
#
# The Kenta Bus : departure event at Collegetown at t = 162.77713937042617
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 168.44821942253097
# After arrival, occupancy = 1
#
# The Kenta Bus : departure event at Commons-Westbound at t = 168.44821942253097
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 169.34821942253097
# After arrival, occupancy = 1
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 169.34821942253097
#
# The Kenta Bus : arrival event at Collegetown at t = 175.58772583038495
# After arrival, occupancy = 1
#
# The Kenta Bus : departure event at Collegetown at t = 175.58772583038495
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 182.0850434922573
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 182.0850434922573
#
# The Kenta Bus : arrival event at Commons-Eastbound at t =
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 870.288562381172
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 876.2007122991934
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 876.2007122991934
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 877.1007122991933
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 877.1007122991933
#
# The Kenta Bus : arrival event at Collegetown at t = 883.1062442218696
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 883.1062442218696
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 888.3058095177964
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 888.3058095177964
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 889.2058095177964
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 889.2058095177964
#
# The Kenta Bus : arrival event at Collegetown at t = 895.8351287941952
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 895.8351287941952
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 902.6742477910283
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 902.6742477910283
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 903.5742477910283
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 903.5742477910283
#
# The Kenta Bus : arrival event at Collegetown at t = 909.9790324482202
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 909.9790324482202
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 916.5779759373103
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 916.5779759373103
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 917.4779759373102
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 917.4779759373102
#
# The Kenta Bus : arrival event at Collegetown at t = 923.3522756870472
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 923.3522756870472
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 930.3126522680442
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 930.3126522680442
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 931.2126522680442
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 931.2126522680442
#
# The Kenta Bus : arrival event at Collegetown at t = 937.1628252394986
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 937.1628252394986
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 942.5770835141216
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 942.5770835141216
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 943.4770835141215
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 943.4770835141215
#
# The Kenta Bus : arrival event at Collegetown at t = 948.7537522516448
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 948.7537522516448
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 954.2456633758233
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 954.2456633758233
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 955.1456633758232
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 955.1456633758232
#
# The Kenta Bus : arrival event at Collegetown at t = 960.564424959776
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 960.564424959776
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 967.1739190508296
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 967.1739190508296
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 968.0739190508295
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 968.0739190508295
#
# The Kenta Bus : arrival event at Collegetown at t = 973.9178409122267
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 973.9178409122267
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 980.2430967471075
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 980.2430967471075
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 981.1430967471075
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 981.1430967471075
#
# The Kenta Bus : arrival event at Collegetown at t = 986.9940693928419
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 986.9940693928419
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 992.4768882880525
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 992.4768882880525
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 993.3768882880524
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 993.3768882880524
#
# The Kenta Bus : arrival event at Collegetown at t = 998.6929179995262
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 998.6929179995262
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 1005.4584286736341
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 1005.4584286736341
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 1006.3584286736341
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 1006.3584286736341
#
# The Kenta Bus : arrival event at Collegetown at t = 1011.8336050596284
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 1011.8336050596284
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 1017.7379272409506
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 1017.7379272409506
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 1018.6379272409506
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 1018.6379272409506
#
# The Kenta Bus : arrival event at Collegetown at t = 1024.166507728493
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 1024.166507728493
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 1030.0276905501507
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 1030.0276905501507
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 1030.9276905501508
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 1030.9276905501508
#
# The Kenta Bus : arrival event at Collegetown at t = 1037.860916019608
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 1037.860916019608
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 1043.199867309885
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 1043.199867309885
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 1044.099867309885
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 1044.099867309885
#
# The Kenta Bus : arrival event at Collegetown at t = 1050.9147664594198
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 1050.9147664594198
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 1056.1768254282704
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 1056.1768254282704
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 1057.0768254282705
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 1057.0768254282705
#
# The Kenta Bus : arrival event at Collegetown at t = 1062.8575865025757
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 1062.8575865025757
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 1068.169232983059
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 1068.169232983059
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 1069.069232983059
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 1069.069232983059
#
# The Kenta Bus : arrival event at Collegetown at t = 1075.5204133679013
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 1075.5204133679013
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 1082.210530128398
