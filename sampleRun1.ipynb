# %%
import numpy as np
from pySimio import *

# %%
# number of people (per origin/destination type) to generate and arrival rate
num_people = 20
LAMBDA = 5

# %%
# assuming people are reasonable, only 6 possible origin/destination pairs exist
WegE_ComE = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
WegE_Ctown = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
ComE_Ctown = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
Ctown_ComW = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
Ctown_WegW = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))
ComW_WegW = list(np.cumsum(np.random.exponential(LAMBDA, num_people)))

# %%
# create a BusStop object for each of the 6 bus stops
TDOG = BusStop('TDOG Depot')
WegE = BusStop('Wegmans-Eastbound')
WegW = BusStop('Wegmans-Westbound')
ComE = BusStop('Commons-Eastbound')
ComW = BusStop('Commons-Westbound')
Ctown = BusStop('Collegetown')

# %%
WegE.add_data({ComE: WegE_ComE, Ctown: WegE_Ctown})
ComE.add_data({Ctown: ComE_Ctown})
ComW.add_data({WegW: ComW_WegW})
Ctown.add_data({ComW: Ctown_ComW, WegW: Ctown_WegW})

# %%
# create a Route object for each of the 3 routes
Route1 = Route([TDOG, WegE, ComE, Ctown, ComW, WegE, TDOG], [0.5, 2, 2, 2, 2, 0.5], 1)
Route2 = Route([ComE, Ctown, ComW, ComE], [2, 2, 0.3], 2)
Route3 = Route([TDOG, WegE, ComE, ComW, WegW, TDOG], [0.5, 2, 2, 2, 0.5], 3)

# %%
# Bus1 = Bus('Bus 1', Route1)
Bus2 = Bus('The Kenta Bus', Route2)

# %%
Ithaca = Map([Route1, Route2, Route2], [Bus2], 
             {'TDOG Depot': TDOG, 'Wegmans-Eastbound': WegE, 'Wegmans-Westbound': WegW,
             'Commons-Eastbound': ComE, 'Commons-Westbound': ComW, 'Collegetown':Ctown})

# %%
Ithaca.simulate(18*60)
# Out:
# 1
# The Kenta Bus : departure event at TDOG Depot at t = 0
#
# The Kenta Bus : arrival event at Wegmans-Eastbound at t = 1.5
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Wegmans-Eastbound at t = 1.5
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 6.623785906135943
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 6.623785906135943
#
# The Kenta Bus : arrival event at Collegetown at t = 11.87072918288544
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 11.87072918288544
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 17.163935868556106
# After arrival, occupancy = 1
#
# The Kenta Bus : departure event at Commons-Westbound at t = 17.163935868556106
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 18.063935868556104
# After arrival, occupancy = 1
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 18.063935868556104
#
# The Kenta Bus : arrival event at Collegetown at t = 24.79060813527008
# After arrival, occupancy = 3
#
# The Kenta Bus : departure event at Collegetown at t = 24.79060813527008
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 30.57089815222645
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Commons-Westbound at t = 30.57089815222645
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 31.47089815222645
# After arrival, occupancy = 4
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 31.47089815222645
#
# The Kenta Bus : arrival event at Collegetown at t = 37.007638113225134
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Collegetown at t = 37.007638113225134
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 42.41481700595453
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Westbound at t = 42.41481700595453
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 43.31481700595453
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 43.31481700595453
#
# The Kenta Bus : arrival event at Collegetown at t = 50.324358807486526
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Collegetown at t = 50.324358807486526
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 56.17195018604952
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Westbound at t = 56.17195018604952
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 57.07195018604952
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 57.07195018604952
#
# The Kenta Bus : arrival event at Collegetown at t = 63.12184739383977
# After arrival, occupancy = 6
#
# The Kenta Bus : departure event at Collegetown at t = 63.12184739383977
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 68.50974288787857
# After arrival, occupancy = 6
#
# The Kenta Bus : departure event at Commons-Westbound at t = 68.50974288787857
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 69.40974288787858
# After arrival, occupancy = 6
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 69.40974288787858
#
# The Kenta Bus : arrival event at Collegetown at t = 75.37890888349
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Collegetown at t = 75.37890888349
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 82.19426426304932
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Commons-Westbound at t = 82.19426426304932
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 83.09426426304933
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 83.09426426304933
#
# The Kenta Bus : arrival event at Collegetown at t = 88.70327984391642
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Collegetown at t = 88.70327984391642
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 95.00580355647364
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Westbound at t = 95.00580355647364
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 95.90580355647364
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 95.90580355647364
#
# The Kenta Bus : arrival event at Collegetown at t = 101.762233355518
# After arrival, occupancy = 6
#
# The Kenta Bus : departure event at Collegetown at t = 101.762233355518
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 108.41706010013802
# After arrival, occupancy = 9
#
# The Kenta Bus : departure event at Commons-Westbound at t = 108.41706010013802
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 109.31706010013802
# After arrival, occupancy = 9
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 109.31706010013802
#
# The Kenta Bus : arrival event at Collegetown at t = 115.01820608458543
# After arrival, occupancy = 8
#
# The Kenta Bus : departure event at Collegetown at t = 115.01820608458543
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 120.51485114397835
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Westbound at t = 120.51485114397835
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 121.41485114397835
# After arrival, occupancy = 7
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 121.41485114397835
#
# The Kenta Bus : arrival event at Collegetown at t = 127.52867458014711
# After arrival, occupancy = 5
#
# The Kenta Bus : departure event at Collegetown at t = 127.52867458014711
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 133.62986660579153
# After arrival, occupancy = 3
#
# The Kenta Bus : departure event at Commons-Westbound at t = 133.62986660579153
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 134.52986660579154
# After arrival, occupancy = 3
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 134.52986660579154
#
# The Kenta Bus : arrival event at Collegetown at t = 140.36942056511836
# After arrival, occupancy = 2
#
# The Kenta Bus : departure event at Collegetown at t = 140.36942056511836
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 146.95670417289202
# After arrival, occupancy = 1
#
# The Kenta Bus : departure event at Commons-Westbound at t = 146.95670417289202
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 147.85670417289202
# After arrival, occupancy = 1
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 147.85670417289202
#
# The Kenta Bus : arrival event at Collegetown at t = 154.5328240394682
# After arrival, occupancy = 1
#
# The Kenta Bus : departure event at Collegetown at t = 154.5328240394682
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 160.43615496058436
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 160.43615496058436
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 161.33615496058437
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 161.33615496058437
#
# The Kenta Bus : arrival event at Collegetown at t = 166.78156087703653
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 166.78156087703653
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 172.86913366611495
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 172.86913366611495
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 173.76913366611495
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 173.76913366611495
#
# The Kenta Bus : arrival event at Collegetown at t = 179.61638619678433
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 179.61638619678433
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 185.28223914898155
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t = 185.28223914898155
#
# The Kenta Bus : arrival event at Commons-Eastbound at t = 186.18223914898155
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Eastbound at t = 186.18223914898155
#
# The Kenta Bus : arrival event at Collegetown at t = 192.32051906982534
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Collegetown at t = 192.32051906982534
#
# The Kenta Bus : arrival event at Commons-Westbound at t = 199.0480327585259
# After arrival, occupancy = 0
#
# The Kenta Bus : departure event at Commons-Westbound at t =